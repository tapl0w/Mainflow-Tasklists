# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
diabetes=pd.read_csv(r"D:\Main flow assingments\Python Datase\Python Dataset\\archive (3)\diabetes_data.csv")

# %%
diabetes.head()
# Out:
#    PatientID  Age  Gender  Ethnicity  SocioeconomicStatus  EducationLevel  \
# 0       6000   44       0          1                    2               1
# 1       6001   51       1          0                    1               2
# 2       6002   89       1          0                    1               3
# 3       6003   21       1          1                    1               2
# 4       6004   27       1          0                    1               3
#
#          BMI  Smoking  AlcoholConsumption  PhysicalActivity  ...  \
# 0  32.985284        1            4.499365          2.443385  ...
# 1  39.916764        0            1.578919          8.301264  ...
# 2  19.782251        0            1.177301          6.103395  ...
# 3  32.376881        1            1.714621          8.645465  ...
# 4  16.808600        0           15.462549          4.629383  ...
#
#    TinglingHandsFeet  QualityOfLifeScore  HeavyMetalsExposure  \
# 0                  1           73.765109                    0
# ...

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('seaborn-v0_8')

# %%
sns.heatmap(diabetes[['Age', 'BMI', 'FastingBloodSugar', 'HbA1c', 'CholesterolTotal', 'CholesterolLDL', 'CholesterolHDL', 'CholesterolTriglycerides']].corr(), annot=True, cmap='cubehelix')
plt.title('Correlation Heatmap')
plt.show()

# %%
diabetes['Ethnicity'].value_counts().plot.pie(autopct='%1.1f%%', colors=sns.color_palette('pastel'))
plt.title('Ethnicity Distribution')
plt.ylabel('')  # Optional to hide y-label
plt.show()

# %%
sns.set_theme()


sns.FacetGrid(diabetes, col="Ethnicity").map(sns.histplot, "Age").set_axis_labels("Age", "Count");
# Out:
# d:\ss\python3\Lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.boxplot(x='Diagnosis', y='QualityOfLifeScore', data=diabetes)
plt.title('Quality of Life Score by Diagnosis')
plt.show()

# %%
sns.countplot(x='HeavyMetalsExposure', hue='Diagnosis', data=diabetes)
plt.title('Heavy Metals Exposure vs. Diagnosis')
plt.show()

# %%
sns.kdeplot(data=diabetes['HbA1c'], shade=True,fill=True)
plt.title('HbA1c Distribution')
plt.show();
# Out:
# C:\Users\manas\AppData\Local\Temp\ipykernel_24724\1764146484.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=diabetes['HbA1c'], shade=True,fill=True)

# %%
sns.swarmplot(x='AlcoholConsumption', y='PhysicalActivity', data=diabetes)
plt.title('Alcohol Consumption vs. Physical Activity')
plt.show()

# %%
sns.countplot(x='Smoking', hue='Diagnosis', data=diabetes,palette='mako')
plt.title('Smoking Status vs. Diabetes Diagnosis')
plt.show()

# %%
sns.swarmplot(x='Ethnicity', y='FastingBloodSugar', data=diabetes)
plt.title('Swarm Plot')
plt.show()
# Out:
# d:\ss\python3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 9.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# d:\ss\python3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 19.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
